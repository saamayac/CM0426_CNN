# %%
from  tensorflow import keras as ks
import visualkeras
import numpy as np

# %%
modelFileName = 'classifier01.h5'
model = ks.models.load_model(modelFileName)
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=502x996>

# %%
print(np.array(img))
